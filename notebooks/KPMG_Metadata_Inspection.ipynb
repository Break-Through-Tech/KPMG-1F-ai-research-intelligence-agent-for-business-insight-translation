# %% [markdown]
# # KPMG arXiv Metadata Inspection
#
# ## Task 2.2 - Explore Metadata Fields
#
# Explore the title, abstract, authors, categories, and submission date fields from the arXiv sample dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/metadata/arxiv_csAI_100_metadata.csv")

# %% [markdown]
# ### Metadata Fields
#
# Inspect the title, abstract, authors, categories, and submission date fields in the arXiv sample.

# %%
df[["title", "abstract", "authors", "categories", "published"]].head()

# %%
df[["title", "abstract", "authors", "categories", "published"]].info()

# %%
df[["title", "abstract", "authors", "categories", "published"]].isnull().sum()

# %% [markdown]
# Inspect sample paper titles to understand how the title field is represented.

# %%
df["title"].head(10)
